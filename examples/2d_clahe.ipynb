# %% [markdown]
# # Application of MCLAHE to an image

# %%
# Load package
import mclahe as mc

import numpy as np
import matplotlib.pyplot as plt
# Out:
# In init py ['/draco/u/vstimper/Material_Informatics/Code/mclahe/examples', '', '/mpcdf/soft/SLE_12_SP3/packages/haswell/tensorflow/gpu/anaconda_3_2019_03-cuda_10_0/1.14.0/lib/python3.7/site-packages', '/u/vstimper/conda-envs/matinf/lib/python37.zip', '/u/vstimper/conda-envs/matinf/lib/python3.7', '/u/vstimper/conda-envs/matinf/lib/python3.7/lib-dynload', '/u/vstimper/conda-envs/matinf/lib/python3.7/site-packages', '/u/vstimper/conda-envs/matinf/lib/python3.7/site-packages/IPython/extensions', '/draco/u/vstimper/.ipython']
# WARNING: Logging before flag parsing goes to stderr.
# W0821 09:24:28.093118 47922978363904 __init__.py:308] Limited tf.compat.v2.summary API due to missing TensorBoard installation.

# %%
# Load and show image with bad contrast
img = plt.imread('../images/example_2d.jpg')
plt.figure(figsize=(12, 9))
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# Apply mclahe
img_mclahe = mc.mclahe(img[:, :, 0])
# Out:
# W0821 09:24:57.942365 47922978363904 deprecation_wrapper.py:119] From /u/vstimper/conda-envs/matinf/lib/python3.7/site-packages/mclahe/mclahe.py:42: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W0821 09:24:57.965454 47922978363904 deprecation_wrapper.py:119] From /u/vstimper/conda-envs/matinf/lib/python3.7/site-packages/mclahe/mclahe.py:43: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0821 09:24:58.073770 47922978363904 deprecation.py:323] From /u/vstimper/conda-envs/matinf/lib/python3.7/site-packages/mclahe/mclahe.py:85: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0821 09:24:58.080307 47922978363904 deprecation_wrapper.py:119] From /u/vstimper/conda-envs/matinf/lib/python3.7/site-packages/mclahe/mclahe.py:91: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# W0821 09:24:58.176189 47922978363904 deprecation_wrapper.py:119] From /u/vstimper/conda-envs/matinf/lib/python3.7/site-packages/mclahe/mclahe.py:123: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W0821 09:24:58.189924 47922978363904 deprecation_wrapper.py:119] From /u/vstimper/conda-envs/matinf/lib/python3.7/site-packages/mclahe/mclahe.py:145: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0821 09:24:58.829574 47922978363904 deprecation_wrapper.py:119] From /u/vstimper/conda-envs/matinf/lib/python3.7/site-packages/mclahe/mclahe.py:157: The name tf.initializers.variables is deprecated. Please use tf.compat.v1.initializers.variables instead.

# %%
# Show result
plt.figure(figsize=(12, 9))
plt.imshow(np.tile(np.expand_dims(img_mclahe, 2), (1, 1, 3)))
plt.axis('off')
plt.show()
